# %% [markdown]
# This data loader:
# 1. Takes in raw gene expression counts
# 2. Selects only genes relevant to our project
# 3. Normalizes gene expression levels to the total expression of each cell
# 4. Splits data into training and testing sets
# 5. Saves the processed data into separate .csv files.
#
# Input and output data loading are separated to prevent overloading of memory.

# %%
import pandas as pd

# %%
# filenames (CHANGE THESE AS NEEDED)
HOME = '/home/jupyter-dylan/'

INPUT_GENE_FILE = '{}gene labels/input_genes.txt'.format(HOME)
OUTPUT_GENE_FILE = '{}gene labels/output_genes-1.txt'.format(HOME)

TRAIN_CELLS_FILE = '{}new_data/train_cells.txt'.format(HOME)
TEST_CELLS_FILE = '{}new_data/test_cells.txt'.format(HOME)

RAW_DATA_FILE = '{}data/GSE115746_cells_exon_counts.csv'.format(HOME)

SUMS_FILE = '{}gene labels/cell_expr_sums.csv'.format(HOME)

SAVE_INPUT_TRAIN = '{}new_data/input_train.csv'.format(HOME)
SAVE_INPUT_TEST = '{}new_data/input_test.csv'.format(HOME)
SAVE_OUTPUT_TRAIN = '{}new_data/output_train-1.csv'.format(HOME)
SAVE_OUTPUT_TEST= '{}new_data/output_test-1.csv'.format(HOME)

# %%
# normalize cell expression counts by total (sum) expression for each cell

# from functools import reduce
# data_load = pd.read_csv(RAW_DATA_FILE, index_col=0, chunksize=10000)
# sums_list = [chunk.sum(axis=0) for chunk in data_load]
# sums = reduce(lambda x, y: x.add(y), sums_list)
# sums.to_csv(SUMS_FILE)

# sums = pd.read_csv(SUMS_FILE)
sums = pd.read_csv(SUMS_FILE, header=0, index_col=0)

# %%
# sanity check
sums
# Out:
#                            0
# F2S4_150422_002_A01  1204630
# F2S4_150422_002_B01  1259862
# F2S4_150422_002_C01  1128827
# F2S4_150422_002_D01   879874
# F2S4_150422_002_E01  1117094
# ...                      ...
# F1S4_180124_317_D01  1022536
# F1S4_180124_317_E01   724679
# F1S4_180124_317_F01   980851
# F1S4_180124_317_G01  1029766
# F1S4_180124_317_H01   965509
#
# [23178 rows x 1 columns]

# %%
# load train and test cells
with open(TRAIN_CELLS_FILE) as f:
    train_cells = [cell.strip() for cell in f]

with open(TEST_CELLS_FILE) as f:
    test_cells = [cell.strip() for cell in f]

# %%
# sanity check
set(train_cells).intersection(set(test_cells))
# Out:
# set()

# %% [markdown]
# # Load input data

# %%
# load input gene names
with open(INPUT_GENE_FILE) as f:
    input_genes = [gene.strip() for gene in f]   # remove '\n' at end of lines

# %%
# sanity check
input_genes
# Out:
# ['Zfp182',
#  'En1',
#  'Tead3',
#  'Pou6f2',
#  'Nfix',
#  'Thra',
#  'Efemp1',
#  'Neurog3',
#  'Rasal3',
#  'Smad5',
#  'Crebbp',
#  'Hif1a',
#  'Suz12',
#  'Onecut1',
#  'Ubp1',
#  'Kat8',
#  'Bhlhe41',
#  'Hoxb5',
#  'Deaf1',
#  'Zfp763',
#  'Klf10',
#  'Nfat5',
#  'Mzf1',
#  'Zkscan1',
#  'Foxj3',
#  'Itgb3bp',
#  'Zfp709',
#  'Nfxl1',
#  'Asxl2',
#  'Emx2',
#  'Tfap2c',
#  'Gm3854',
#  'Cxxc1',
#  'Insr',
#  'Pou3f2',
#  'Spib',
#  'Tbx3',
#  'Rax',
#  'Taf1',
#  'Csrnp2',
#  'Zfp319',
#  'Mnx1',
#  'Zfp110',
#  'Foxe3',
#  'Trp73',
#  'Mta1',
#  'Arid3a',
#  'Tmpo',
#  'Ppara',
#  'Pcgf6',
#  'Zfp59',
#  'Shh',
#  'Trp53inp1',
#  'Foxp1',
#  'Plag1',
#  'Gsc',
#  'Sbno2',
#  'Zfp280b',
#  'Pou5f1',
#  'Ets1',
#  'Myog',
#  'Cds1',
#  'Tcf7',
#  'Dlx1',
#  'Barx2',
#  'Stat6',
#  'Zfp280c',
#  'Prdm15',
#  'Zgpat',
#  'Pitx2',
#  'Sox5',
#  'Foxb1',
#  'Ntn3',
#  'Bax',
#  'Wiz',
#  'Emx1',
#  'Dmrtc2',
#  'Lpin1',
#  'Znfx1',
#  'Mterf1a',
#  'Zfp82',
#  'Gm14325',
#  'Mga',
#  'Creb3l2',
#  'Lhx6',
#  'Eaf2',
#  'Nkx6-3',
#  'Lyl1',
#  'Mbtd1',
#  'Neurod6',
#  'Atxn1l',
#  'Dlx2',
#  'E2f7',
#  'Spic',
#  'Hif3a',
#  'Prdm13',
#  'Bhlha15',
#  'Hinfp',
#  'Ajuba',
#  'Zfp369',
#  'Hand2',
#  'Taf7',
#  'Mitf',
#  'Pax5',
#  'Prkci',
#  'Csrnp3',
#  'Vhl',
#  'Ascl5',
#  'Klf11',
#  'Fads1',
#  'Obox5',
#  'Cfl1',
#  'Prdm16',
#  'Bcl11b',
#  'Otx1',
#  'Atf6',
#  'Ybx1',
#  'Phf5a',
#  'Insm1',
#  'Zfp647',
#  'Irf2',
#  'Six3',
#  'Mycs',
#  'Onecut2',
#  'Zscan12',
#  'Zfp853',
#  'Sin3a',
#  'Zfp341',
#  'Gm20737',
#  'Ovol2',
#  'Cdca7',
#  'Smad2',
#  'Srebf1',
#  'Ahrr',
#  'Myb',
#  'Obox1',
#  'Dazap2',
#  'Ube2l3',
#  'Phf19',
#  'Hdac1',
#  'Ppard',
#  'Vgll4',
#  'Arnt',
#  'Homez',
#  'Cited2',
#  'Ncoa2',
#  'Adora2a',
#  'Pdlim1',
#  'St18',
#  'Apbb3',
#  'Mkx',
#  'Rpl18',
#  'Kmt2b',
#  'Gm14322',
#  'Lrif1',
#  'Tcf20',
#  'Batf',
#  'Srebf2',
#  'Zfp36',
#  'Cdx4',
#  'Ror2',
#  'Hoxd1',
#  'Mapk8ip1',
#  'Clock',
#  'Tfe3',
#  'Med1',
#  'Ikzf5',
#  'Crebrf',
#  'Klf15',
#  'Hira',
#  'Rfx7',
#  'Gsx1',
#  'Hlf',
#  'Prrx2',
#  'Nr2f2',
#  'Zkscan14',
#  'Zfp740',
#  'Foxm1',
#  'Gata2',
#  'Lrp6',
#  'Elf4',
#  'Foxi1',
#  'Zfp42',
#  'Ovol1',
#  'Aes',
#  'Pbx1',
#  'Irf3',
#  'Ccnl1',
#  'Acvrl1',
#  'Nr6a1',
#  'Zfp382',
#  'Terf2ip',
#  'Cbfa2t3',
#  'Trp53bp1',
#  'Gm21310',
#  'Hist1h1a',
#  'Zscan20',
#  'Arx',
#  'Hoxc5',
#  'Rb1',
#  'Pou3f4',
#  'Hoxd9',
#  'E2f1',
#  'Tcea1',
#  'Rbm14',
#  'Spdef',
#  'Nkx6-1',
#  'Rcor1',
#  'Spz1',
#  'Creb3l1',
#  'Zfp422',
#  'Batf2',
#  'Hoxb13',
#  'Elk1',
#  'Zfx',
#  'Bach1',
#  'Mesp2',
#  'Tcerg1',
#  'Sap30l',
#  'Zbtb32',
#  'Nr1h2',
#  'Zic1',
#  'Gm21292',
#  'Dach1',
#  'Zfp329',
#  'Cux2',
#  'Rcor2',
#  'Tead4',
#  'Klf12',
#  'Dmrt2',
#  'Mef2b',
#  'Scrt1',
#  'Apbb2',
#  'Gata4',
#  'Max',
#  'Setd2',
#  'Aebp2',
#  'Gm20738',
#  'Notch4',
#  'Sox1',
#  'Sfmbt1',
#  'Arnt2',
#  'Tgif1',
#  'Zfp738',
#  'Chn1',
#  'Tbx19',
#  'Gm20826',
#  'Brca2',
#  'Zfp770',
#  'Hoxd10',
#  'Foxn3',
#  'Gata5',
#  'Car1',
#  'Hic1',
#  'Klf7',
#  'E2f2',
#  'Zkscan6',
#  'Ern2',
#  'Ankrd1',
#  'Ppargc1b',
#  'Nab2',
#  'Nkx1-1',
#  'Ntn4',
#  'Nfya',
#  'Lhx5',
#  'Pfdn5',
#  'Chek2',
#  'Shox2',
#  'Mycn',
#  'Mn1',
#  'Tec',
#  'Zfp936',
#  'Foxo4',
#  'Elf1',
#  'Nkx2-4',
#  'Gabpa',
#  'Cirh1a',
#  'Rxrg',
#  'Etv3',
#  'Gm4924',
#  'Ctr9',
#  'Mpp2',
#  'Eaf1',
#  'Prrxl1',
#  'Ets2',
#  'Smad9',
#  'Nfe2l3',
#  'Trappc2',
#  'Hoxc10',
#  'Srsf10',
#  'Atad2',
#  'Zfp759',
#  'Hlx',
#  'Zfp639',
#  'Pax4',
#  'Sox30',
#  'Hnf1a',
#  'Mef2a',
#  'Prdm1',
#  'Zfp383',
#  'Lhx3',
#  'Prkdc',
#  'Sox17',
#  'Hhex',
#  'Phb',
#  'Prop1',
#  'Fosb',
#  'Zfp14',
#  'Zfp51',
#  'Whsc1l1',
#  'Mafg',
#  'Gm21778',
#  'Ciita',
#  'Npas1',
#  'Pax7',
#  'Msx2',
#  'Zfp92',
#  'H1foo',
#  'Cbfb',
#  'Prox1',
#  'Gm20873',
#  'Zfp689',
#  'Lin54',
#  'Cdx2',
#  'Khsrp',
#  'Sall1',
#  'Trrap',
#  'Rest',
#  'Hsf2',
#  'Pml',
#  'Barhl1',
#  'Mxi1',
#  'Foxf2',
#  'Esp1',
#  'Bach2',
#  'Tcf4',
#  'Gsx2',
#  'Creb3l4',
#  'Zfp583',
#  'Alx1',
#  'Pan2',
#  'Atoh1',
#  'Neo1',
#  'Hist1h1c',
#  'Dmbx1',
#  'Zfp810',
#  'Gatad1',
#  'Sin3b',
#  'Nrl',
#  'Nsd1',
#  'Mterf3',
#  'Sox6',
#  'Zfp28',
#  'Aire',
#  'Lmo4',
#  'Foxp2',
#  'Lrrfip1',
#  'Nfic',
#  'Zfp146',
#  'Prdm14',
#  'Foxk1',
#  'Stat5a',
#  'Crebzf',
#  'Erf',
#  'Mkl1',
#  'Foxf1',
#  'Zfp748',
#  'Pbx2',
#  'Etv2',
#  'Irf9',
#  'Npas4',
#  'Ski',
#  'Atf7ip',
#  'Nrbf2',
#  'Zkscan17',
#  'Nkx3-2',
#  'Nfx1',
#  'Nfe2l1',
#  'Six5',
#  'Cdk4',
#  'Mixl1',
#  'Zfp236',
#  'Mum1',
#  'Foxq1',
#  'Med23',
#  'Hdac2',
#  'Nr4a2',
#  'Tbp',
#  'Six4',
#  'Sry',
#  'Vgll3',
#  'Obox2',
#  'Tbx6',
#  'Etv4',
#  'Zfp322a',
#  'Zfp938',
#  'Sp4',
#  'Atoh7',
#  'Vsx2',
#  'Zfp786',
#  'Taf1d',
#  'Cebpd',
#  'Hoxa4',
#  'Dmrt3',
#  'Sp3',
#  'Myf6',
#  'Mafa',
#  'Creb3l3',
#  'Spin2d',
#  'Ear1',
#  'Hoxc4',
#  'A430033K04Rik',
#  'Tram1',
#  'Apex1',
#  'Zbtb14',
#  'Ralgapa1',
#  'Elk3',
#  'Carf',
#  'Gm20795',
#  'Trps1',
#  'Gm20806',
#  'Cnot3',
#  'Esrra',
#  'Mal',
#  'Me1',
#  'Tle4',
#  'Elmsan1',
#  'Zfat',
#  'Vsx1',
#  'Dmrta1',
#  'Alx3',
#  'Atoh8',
#  'Sap25',
#  'Tbl1x',
#  'Bhlhe40',
#  'Tle3',
#  'Ikzf3',
#  'Ifnk',
#  'Asxl1',
#  'Patz1',
#  'Nup35',
#  'Emb',
#  'Cited1',
#  'Zscan4f',
#  'Isl2',
#  'Atxn1',
#  'Zfp746',
#  'Spi1',
#  'Zfp2',
#  'Mterf2',
#  'Irx6',
#  'Prb1',
#  'Rnf20',
#  'Gmeb1',
#  'Ctcf',
#  'Zfp600',
#  'Hnf4a',
#  'Kat2a',
#  'Zbtb16',
#  'Neurod4',
#  'Hes5',
#  'Nr2f1',
#  'Nfyb',
#  'Hoxb4',
#  'Snai2',
#  'Tfam',
#  'Cux1',
#  'Hils1',
#  'Pou2f3',
#  'Meis3',
#  'Heyl',
#  'Tbx20',
#  'Med27',
#  'Zfp54',
#  'Sox9',
#  'Zfp809',
#  'Erg',
#  'AI987944',
#  'Ascl4',
#  'Tlx3',
#  'Bcl11a',
#  'Hoxa6',
#  'Mesp1',
#  'Zfp473',
#  'Zscan22',
#  'Isl1',
#  'Sst',
#  'Supt4a',
#  'Hoxd13',
#  'Epas1',
#  'Tle1',
#  'Gcm2',
#  'Zfp955b',
#  'Sox4',
#  'Dmrtc1a',
#  'Me2',
#  'Spin1',
#  'Gm20773',
#  'Cebpa',
#  'Zfp367',
#  'Rbl2',
#  'Helt',
#  'Mecp2',
#  'Pou1f1',
#  'Mtl5',
#  'Zfp157',
#  'Onecut3',
#  'Dbx1',
#  'E2f4',
#  'Atf5',
#  'Cnot2',
#  'Rbpj',
#  'Stat1',
#  'Mapk14',
#  'Ehf',
#  'Med15',
#  'Mnat1',
#  'Sms',
#  'Foxs1',
#  'Lhx4',
#  'Mybl1',
#  'Etv1',
#  'Ptp4a3',
#  'Otx2',
#  'Runx1t1',
#  'Taf10',
#  'Zfhx3',
#  '2210018M11Rik',
#  'Sohlh2',
#  'Mterf4',
#  'Mycl',
#  'Ep300',
#  'Rarg',
#  'Arid2',
#  'E2f5',
#  'Pbx3',
#  'Zfp641',
#  'Asxl3',
#  'Rarb',
#  'Cdk2',
#  'Zfp869',
#  'Kdm3b',
#  'Bdp1',
#  'Carm1',
#  'Gm20807',
#  'Cdc14b',
#  'Ss18l1',
#  'Grm5',
#  'Hes2',
#  'Nfia',
#  'Irx2',
#  'Hsf1',
#  'Rel',
#  'Fev',
#  'Ppie',
#  'Scmh1',
#  'Arntl2',
#  'Snf8',
#  'Ssty1',
#  'Sohlh1',
#  'Actrt1',
#  'Zfp959',
#  'Mina',
#  'Nfyc',
#  'Ifng',
#  'Nono',
#  'Pitx1',
#  'Sim1',
#  'Nr4a1',
#  'Pax8',
#  'Sap130',
#  'Arntl',
#  'Hdac10',
#  'Zfp595',
#  'Snai3',
#  'Sra1',
#  'Keap1',
#  'Nlk',
#  'Zfp703',
#  'Hcfc1',
#  'Foxo3',
#  'Zfp30',
#  'Morf4l2',
#  'Pogk',
#  'H1fx',
#  'Atf4',
#  'Naa15',
#  'Usf2',
#  'Zfy2',
#  'Zfp518b',
#  'Gata3',
#  'Pou4f1',
#  'Mrgbp',
#  'Xbp1',
#  'Dcp1a',
#  'Sox2',
#  'Neurog1',
#  'Zfp41',
#  'Rbak',
#  'Zfp932',
#  'Gsc2',
#  'Atf6b',
#  'Mypop',
#  'Gcfc2',
#  'Zfp957',
#  'Phf1',
#  'Tead1',
#  'Purb',
#  'Tceb2',
#  'Tcea3',
#  'Mafk',
#  'Taf6',
#  'Hoxa3',
#  'Nkx2-2',
#  'Trip4',
#  'Lhx8',
#  'Hnf1b',
#  'Atp1b4',
#  'Zfp1',
#  'Cbfa2t2',
#  'Cops5',
#  'Rbp3',
#  'Msl3',
#  'Foxb2',
#  'Lbh',
#  'Nr1i3',
#  'Elf3',
#  'Hoxb6',
#  'Pitx3',
#  'Hcfc2',
#  'Maf',
#  '2610008E11Rik',
#  'Smad6',
#  'Ncor1',
#  'Sall3',
#  'Snapc5',
#  'Hsf5',
#  'Bhlhe23',
#  'Bsx',
#  'Foxr1',
#  'Nkx2-3',
#  'Gcm1',
#  'Rxra',
#  'Sp1',
#  'Phf2',
#  'Zfp426',
#  'Hist1h1t',
#  'Nfe2l2',
#  'Hivep2',
#  'Stat3',
#  'Gtf2h3',
#  'Hes1',
#  'Mta2',
#  'Sox11',
#  'Hmgb4',
#  'Hoxd12',
#  'Nup107',
#  'Prdm6',
#  'Drap1',
#  'Klf5',
#  'Prdm12',
#  'Vgll2',
#  'Gm21964',
#  'Tle2',
#  'Gm14391',
#  'Olig1',
#  'Zfp40',
#  'Zscan10',
#  'Elf2',
#  'Runx1',
#  'Myrf',
#  'Pgr',
#  'Tfcp2',
#  'Pax9',
#  'Mecom',
#  'Six6',
#  'Rslcan18',
#  'Lhx2',
#  'Creb1',
#  'Hmg20b',
#  'Foxo6',
#  'Hsf3',
#  'Gm20852',
#  'Zfp69',
#  'Hnf4g',
#  'Hsf4',
#  'Isx',
#  'Ddit3',
#  'Foxo1',
#  'Pax3',
#  'Foxn1',
#  'Hesx1',
#  'Satb2',
#  'Dlx6',
#  'Zscan4d',
#  'Vps72',
#  'Foxc1',
#  'Add1',
#  'Zfp13',
#  'Bmp2',
#  'Zfp458',
#  'Nr4a3',
#  'Pdx1',
#  'Scx',
#  'Nanog',
#  'Nr0b1',
#  'Hoxc12',
#  'Zfp644',
#  'Casz1',
#  'Vax2',
#  'Mtf1',
#  'Rnf6',
#  'Brdt',
#  'Etohi1',
#  'Tfap2b',
#  'Ikzf2',
#  'Pou3f1',
#  'Tbr1',
#  'Hes7',
#  'Hoxd8',
#  'Foxd3',
#  'Hes6',
#  'Fosl2',
#  'Pinx1',
#  'Hmga2',
#  'Xrcc6',
#  'Runx2',
#  'Zfp143',
#  'Rac3',
#  '9430076C15Rik',
#  'Cited4',
#  'Ebf3',
#  'Jun',
#  'Zik1',
#  'Gm20816',
#  'Meox2',
#  'Nos2',
#  'Spin4',
#  'A530054K11Rik',
#  'Yy2',
#  'Gm20815',
#  'Nfkb1',
#  'Supt5',
#  'Aebp1',
#  'Actr5',
#  'Sox15',
#  'Sfmbt2',
#  'Med7',
#  'Ncoa6',
#  'Fzd7',
#  'Vgll1',
#  'Tbx22',
#  'Hoxb8',
#  'Lhx9',
#  'Pbx4',
#  'Tcf7l1',
#  'Ecsit',
#  'Rfx2',
#  'Six1',
#  'Ttf1',
#  'Stat4',
#  'Etv6',
#  'Ikzf4',
#  'Mef2c',
#  'Sox13',
#  'Ncoa1',
#  'Gpbp1',
#  'Nkx2-9',
#  'Atl1',
#  'Pparg',
#  'Actr8',
#  'Creg1',
#  'Rorb',
#  'T',
#  'Alx4',
#  'Nelfe',
#  'Ptx3',
#  'Ahr',
#  'Zfp821',
#  'Nkx1-2',
#  'Apbb1',
#  'Zfp354c',
#  'Nfatc3',
#  'Hap1',
#  'Tcf12',
#  'Nr3c1',
#  'Pou4f3',
#  'Zscan21',
#  'Rbl1',
#  'Kmt2c',
#  'Meis1',
#  'Zfp445',
#  'Trap1',
#  'Crebl2',
#  'Zfp46',
#  'Esr1',
#  'Zfy1',
#  'Zfhx4',
#  'Smad4',
#  'Ldb3',
#  'Arid5b',
#  'BC025920',
#  'Zfp60',
#  'Hmgb1',
#  'Ing2',
#  'H1f0',
#  'Scrt2',
#  'Yeats4',
#  'Lrrfip2',
#  'Parp1',
#  'Hoxa7',
#  'Mybbp1a',
#  'Prdm9',
#  'Zbtb41',
#  'Hist1h1d',
#  'Pax1',
#  'Tsc22d3',
#  'Neurog2',
#  'Kmt2a',
#  'Foxj2',
#  'Zfp64',
#  'Zfp119a',
#  'Zfp180',
#  'Nkx6-2',
#  'Gm20822',
#  'Pa2g4',
#  'Fos',
#  'Gm20854',
#  'Usf1',
#  'Obox6',
#  'Cebpe',
#  'E2f6',
#  'Dlx5',
#  'Celsr2',
#  'Zfp184',
#  'Msgn1',
#  'Msx3',
#  'Evx1',
#  'Kat6a',
#  'Sall4',
#  'Zbtb38',
#  'Rela',
#  'Whsc1',
#  'Gm20747',
#  'Nr1h3',
#  'Meox1',
#  'Ascl3',
#  'Maff',
#  'Nrf1',
#  'Notch3',
#  'Rnr1',
#  'Mier1',
#  'Snai1',
#  'Ldb2',
#  'Daxx',
#  'Cebpb',
#  'Mtf2',
#  'Atf2',
#  'Rreb1',
#  'Zfp467',
#  'Hey1',
#  'Zfp558',
#  'Bex1',
#  'Trp63',
#  'Dlx4',
#  'Zbtb24',
#  'Foxh1',
#  'Crx',
#  'Cdx1',
#  'Hp1bp3',
#  'Ror1',
#  'Sox18',
#  'D3Ertd254e',
#  'ND1',
#  'Cklf',
#  'Kdm1a',
#  'Eomes',
#  'Ewsr1',
#  'Ndnl2',
#  'Myt1l',
#  'Mlxipl',
#  'Gm13212',
#  'Nfatc4',
#  'Spp1',
#  'Taf6l',
#  'Rbpjl',
#  'Pias2',
#  'Zfp628',
#  'Lmo2',
#  'Hax1',
#  'Esrrb',
#  'Zfp513',
#  'Mlx',
#  'Musk',
#  'Tlx2',
#  'Zfp735',
#  'Zfp354a',
#  'Prdm11',
#  'Nr2f6',
#  'Hn1',
#  'Mlf1',
#  'Ascc1',
#  'Brf1',
#  'Zfp219',
#  'Hmgb2',
#  'Jdp2',
#  'Zfp668',
#  'Hint2',
#  'Zfp541',
#  'Tbx5',
#  'En2',
#  'Nr3c2',
#  'Rfx1',
#  'Zfp316',
#  'Myrfl',
#  'L3mbtl4',
#  'Prmt5',
#  'Junb',
#  'Tbpl2',
#  'Smad1',
#  'Hmx1',
#  'Mkl2',
#  'Limd1',
#  'Bcl3',
#  'Slc39a8',
#  'Ncoa3',
#  'Zfp93',
#  'Hoxc8',
#  'Hbp1',
#  'Tbx2',
#  'Thap1',
#  'Skor2',
#  'Thrb',
#  'Tbx10',
#  'Zhx2',
#  'Duxbl1',
#  'Tfap2e',
#  'Gata6',
#  'Zfp616',
#  'Pax6',
#  'Klf17',
#  'Zfp952',
#  'Cks1b',
#  'Crxos',
#  'Foxn4',
#  'Smarca1',
#  'Foxd4',
#  'Zfp955a',
#  'Safb',
#  'Dmrtb1',
#  'Abt1',
#  'Zfp626',
#  'Gbx2',
#  'Gfi1b',
#  'Sub1',
#  'Paxbp1',
#  'Mycbp',
#  'Dmrt1',
#  'Foxa2',
#  'Atf1',
#  'Tfb2m',
#  'Nr2c1',
#  'Nobox',
#  'Myod1',
#  'Tsc22d1',
#  'AA987161',
#  'Nr1d2',
#  'Zbtb7b',
#  'Vit',
#  'Hnrnpab',
#  'Zfp58',
#  'Prox2',
#  'Aff1',
#  'Zfp27',
#  'Tbx21',
#  'Glis3',
#  'Ascl1',
#  'Zfp287',
#  'Med17',
#  'Zfhx2',
#  'Myc',
#  'Cebpz',
#  'Zfp617',
#  'Barhl2',
#  'Hes3',
#  'Foxg1',
#  'Foxe1',
#  'Hoxa2',
#  'Gm12845',
#  'Zfp551',
#  'Zmpste24',
#  'Gm20865',
#  'Senp2',
#  'Ebf1',
#  'Hoxc9',
#  'Zfp90',
#  'Smarca4',
#  'Zfp354b',
#  'Gm10770',
#  'Zfp74',
#  ...]

# %%
# 1. load input data
# 2. only load genes of interest to conserve memory
data_load = pd.read_csv(RAW_DATA_FILE, index_col=0, chunksize=5000)
input_data = pd.concat([chunk.iloc[chunk.index.map(lambda x: x in input_genes)] for chunk in data_load])

# %%
# sanity check
input_data.head()
# Out:
#                F2S4_150422_002_A01  F2S4_150422_002_B01  F2S4_150422_002_C01  \
# 2210018M11Rik                  101                   25                  118
# 2610008E11Rik                   86                  151                    6
# 2810021J22Rik                   32                   13                    0
# 9130023H24Rik                    0                    0                    0
# 9430076C15Rik                    0                    0                    0
#
#                F2S4_150422_002_D01  F2S4_150422_002_E01  F2S4_150422_002_F01  \
# 2210018M11Rik                   49                  104                   97
# 2610008E11Rik                    0                   14                    8
# 2810021J22Rik                   30                    0                    2
# 9130023H24Rik                    0                    2                    0
# 9430076C15Rik                    0                    0                    0
#
#                F2S4_150422_002_G01  F2S4_150422_002_H01  F2S4_150427_001_A01  \
# 2210018M11Rik                   61                  191                   57
# 2610008E11Rik                   62                  176                   64
# 2810021J22Rik                    0                   15                    2
# 9130023H24Rik                    0                    0                    0
# 9430076C15Rik                    0                    0                    0
#
#                F2S4_150427_001_B01  ...  F1S4_180124_316_G01  \
# 2210018M11Rik                  156  ...                   48
# 2610008E11Rik                    6  ...                   35
# 2810021J22Rik                    1  ...                    1
# 9130023H24Rik                    0  ...                    0
# 9430076C15Rik                    0  ...                    0
#
#                F1S4_180124_316_H01  F1S4_180124_317_A01  F1S4_180124_317_B01  \
# 2210018M11Rik                   56                   67                   55
# 2610008E11Rik                    0                   67                   18
# 2810021J22Rik                    0                   48                    2
# 9130023H24Rik                    0                    0                    0
# 9430076C15Rik                    0                    0                    0
#
#                F1S4_180124_317_C01  F1S4_180124_317_D01  F1S4_180124_317_E01  \
# 2210018M11Rik                    3                   57                   34
# 2610008E11Rik                    0                    0                   16
# 2810021J22Rik                    0                    0                    0
# 9130023H24Rik                    0                    0                    0
# 9430076C15Rik                    0                    0                    0
#
#                F1S4_180124_317_F01  F1S4_180124_317_G01  F1S4_180124_317_H01
# 2210018M11Rik                   64                   35                   20
# 2610008E11Rik                    0                   19                   11
# 2810021J22Rik                   63                    0                    0
# 9130023H24Rik                    1                    1                    0
# 9430076C15Rik                    0                    0                    0
#
# [5 rows x 23178 columns]

# %%
del input_genes

# %%
# 3. normalize input data
input_data_norm = input_data.div(sums['0'], axis=1)

# %%
# sanity check
input_data_norm.head()
# Out:
#                F2S4_150422_002_A01  F2S4_150422_002_B01  F2S4_150422_002_C01  \
# 2210018M11Rik             0.000084              0.00002             0.000105
# 2610008E11Rik             0.000071              0.00012             0.000005
# 2810021J22Rik             0.000027              0.00001             0.000000
# 9130023H24Rik             0.000000              0.00000             0.000000
# 9430076C15Rik             0.000000              0.00000             0.000000
#
#                F2S4_150422_002_D01  F2S4_150422_002_E01  F2S4_150422_002_F01  \
# 2210018M11Rik             0.000056             0.000093             0.000082
# 2610008E11Rik             0.000000             0.000013             0.000007
# 2810021J22Rik             0.000034             0.000000             0.000002
# 9130023H24Rik             0.000000             0.000002             0.000000
# 9430076C15Rik             0.000000             0.000000             0.000000
#
#                F2S4_150422_002_G01  F2S4_150422_002_H01  F2S4_150427_001_A01  \
# 2210018M11Rik             0.000060             0.000164             0.000052
# 2610008E11Rik             0.000061             0.000151             0.000058
# 2810021J22Rik             0.000000             0.000013             0.000002
# 9130023H24Rik             0.000000             0.000000             0.000000
# 9430076C15Rik             0.000000             0.000000             0.000000
#
#                F2S4_150427_001_B01  ...  F1S4_180124_316_G01  \
# 2210018M11Rik         8.036018e-05  ...             0.000066
# 2610008E11Rik         3.090776e-06  ...             0.000048
# 2810021J22Rik         5.151293e-07  ...             0.000001
# 9130023H24Rik         0.000000e+00  ...             0.000000
# 9430076C15Rik         0.000000e+00  ...             0.000000
#
#                F1S4_180124_316_H01  F1S4_180124_317_A01  F1S4_180124_317_B01  \
# 2210018M11Rik             0.000057             0.000065             0.000047
# 2610008E11Rik             0.000000             0.000065             0.000015
# 2810021J22Rik             0.000000             0.000046             0.000002
# 9130023H24Rik             0.000000             0.000000             0.000000
# 9430076C15Rik             0.000000             0.000000             0.000000
#
#                F1S4_180124_317_C01  F1S4_180124_317_D01  F1S4_180124_317_E01  \
# 2210018M11Rik             0.000005             0.000056             0.000047
# 2610008E11Rik             0.000000             0.000000             0.000022
# 2810021J22Rik             0.000000             0.000000             0.000000
# 9130023H24Rik             0.000000             0.000000             0.000000
# 9430076C15Rik             0.000000             0.000000             0.000000
#
#                F1S4_180124_317_F01  F1S4_180124_317_G01  F1S4_180124_317_H01
# 2210018M11Rik             0.000065         3.398830e-05             0.000021
# 2610008E11Rik             0.000000         1.845079e-05             0.000011
# 2810021J22Rik             0.000064         0.000000e+00             0.000000
# 9130023H24Rik             0.000001         9.710944e-07             0.000000
# 9430076C15Rik             0.000000         0.000000e+00             0.000000
#
# [5 rows x 23178 columns]

# %%
# transpose input data
# ensures that each row is an example and each column is a feature (gene)
# this form is (more) ready to feed into a model
input_data_norm = input_data_norm.transpose()

# %%
# 4. input test/train split
input_train = input_data_norm.loc[input_data_norm.index.map(lambda x: x in train_cells)]
input_test = input_data_norm.loc[input_data_norm.index.map(lambda x: x in test_cells)]

# %%
# sanity check
input_test.head()
# Out:
#                      2210018M11Rik  2610008E11Rik  2810021J22Rik  \
# F2S4_150422_002_B01       0.000020       0.000120       0.000010
# F2S4_150422_002_D01       0.000056       0.000000       0.000034
# F2S4_150422_002_H01       0.000164       0.000151       0.000013
# F2S4_150428_001_A01       0.000128       0.000027       0.000000
# F2S4_150430_003_E01       0.000057       0.000016       0.000001
#
#                      9130023H24Rik  9430076C15Rik  A430033K04Rik  \
# F2S4_150422_002_B01            0.0            0.0   7.937377e-07
# F2S4_150422_002_D01            0.0            0.0   0.000000e+00
# F2S4_150422_002_H01            0.0            0.0   4.289577e-05
# F2S4_150428_001_A01            0.0            0.0   1.081749e-06
# F2S4_150430_003_E01            0.0            0.0   1.457974e-05
#
#                      A530054K11Rik  AA987161  AI987944      AU041133  ...  \
# F2S4_150422_002_B01       0.000000  0.000004  0.000000  9.524853e-06  ...
# F2S4_150422_002_D01       0.000014  0.000000  0.000060  9.092211e-06  ...
# F2S4_150422_002_H01       0.000000  0.000033  0.000058  8.579155e-07  ...
# F2S4_150428_001_A01       0.000000  0.000000  0.000000  0.000000e+00  ...
# F2S4_150430_003_E01       0.000067  0.000000  0.000010  0.000000e+00  ...
#
#                           Zscan12  Zscan2  Zscan20   Zscan21   Zscan22  \
# F2S4_150422_002_B01  7.937377e-07     0.0      0.0  0.000013  0.000000
# F2S4_150422_002_D01  6.591853e-05     0.0      0.0  0.000081  0.000000
# F2S4_150422_002_H01  0.000000e+00     0.0      0.0  0.000005  0.000048
# F2S4_150428_001_A01  3.028898e-05     0.0      0.0  0.000090  0.000050
# F2S4_150430_003_E01  1.943965e-05     0.0      0.0  0.000015  0.000015
#
#                       Zscan26  Zscan4c  Zscan4d  Zscan4f      Zxdc
# F2S4_150422_002_B01  0.000006      0.0      0.0      0.0  0.000002
# F2S4_150422_002_D01  0.000024      0.0      0.0      0.0  0.000001
# F2S4_150422_002_H01  0.000004      0.0      0.0      0.0  0.000000
# F2S4_150428_001_A01  0.000043      0.0      0.0      0.0  0.000000
# F2S4_150430_003_E01  0.000000      0.0      0.0      0.0  0.000005
#
# [5 rows x 1421 columns]

# %%
# 5. save input dataframes as new .csv files to save time when loading
input_train.to_csv(SAVE_INPUT_TRAIN)
input_test.to_csv(SAVE_INPUT_TEST)

# %%
del input_train, input_test, input_data

# %% [markdown]
# # Load output data

# %%
# load output gene names
with open(OUTPUT_GENE_FILE) as f:
    output_genes = [gene.strip() for gene in f]   # remove '\n' at end of lines

# %%
# sanity check
output_genes
# Out:
# ['App',
#  'Apoe',
#  'Gusb',
#  'Lamp5',
#  'Mbp',
#  'Pvalb',
#  'S100b',
#  'Slc30a3',
#  'Snca',
#  'Mapt']

# %%
# 1. load output data
# 2. only load genes of interest to conserve memory
data_load = pd.read_csv(RAW_DATA_FILE, index_col=0, chunksize=5000)
output_data = pd.concat([chunk.iloc[chunk.index.map(lambda x: x in output_genes)] for chunk in data_load])

# %%
# sanity check
output_data.head()

# %%
del output_genes

# %%
# 3. normalize output data
output_data_norm = output_data.div(sums['0'], axis=1)

# %%
# sanity check
output_data_norm.head()

# %%
# transpose output data
# ensures that each row is an example and each column is a feature (gene)
# this form is (more) ready to feed into a model
output_data_norm = output_data_norm.transpose()

# %%
# 4. output test/train split
output_train = output_data_norm.loc[output_data_norm.index.map(lambda x: x in train_cells)]
output_test = output_data_norm.loc[output_data_norm.index.map(lambda x: x in test_cells)]

# %%
# sanity check
output_test.head()

# %%
# 5. save input dataframes as new .csv files to save time when loading
output_train.to_csv(SAVE_OUTPUT_TRAIN)
output_test.to_csv(SAVE_OUTPUT_TEST)

# %%
del output_train, output_test, output_data
