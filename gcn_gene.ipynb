# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
import csv
import copy
from torch import nn
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv, global_mean_pool

# %% [markdown]
# ## Load data

# %%
gene_name = np.loadtxt('gene_name.txt', dtype=str)
gene_edge = np.loadtxt('gene_edge.txt', dtype=str)

# %%
# create mapping table from genes to nodes number
node_map = {}
for i, j in enumerate(gene_name): 
    node_map.update({j:i})

# %%
edge_list = []
for k, i in enumerate(gene_edge): 
    
    letter_count = 0
    while i[letter_count] is not '|': 
        letter_count += 1
        
    first_gene = i[:letter_count]
    second_gene = i[letter_count+1:]
    
    try: 
        node_map[first_gene]
        node_map[second_gene]
        edge_list.append([node_map[first_gene], node_map[second_gene]])
        edge_list.append([node_map[second_gene], node_map[first_gene]])
    except: 
        print('could not fine gene name at %dth line of gene edge' %k)
# Out:
# could not fine gene name at 469th line of gene edge
# could not fine gene name at 527th line of gene edge
# could not fine gene name at 645th line of gene edge
# could not fine gene name at 692th line of gene edge
# could not fine gene name at 808th line of gene edge
# could not fine gene name at 1133th line of gene edge
# could not fine gene name at 1450th line of gene edge
# could not fine gene name at 1496th line of gene edge
# could not fine gene name at 1560th line of gene edge
# could not fine gene name at 1561th line of gene edge
# could not fine gene name at 1562th line of gene edge
# could not fine gene name at 1563th line of gene edge
# could not fine gene name at 1564th line of gene edge
# could not fine gene name at 1565th line of gene edge
# could not fine gene name at 1566th line of gene edge
# could not fine gene name at 1567th line of gene edge
# could not fine gene name at 1568th line of gene edge
# could not fine gene name at 1569th line of gene edge
# could not fine gene name at 1570th line of gene edge
# could not fine gene name at 1571th line of gene edge
# could not fine gene name at 1572th line of gene edge
# could not fine gene name at 1573th line of gene edge
# could not fine gene name at 1574th line of gene edge
# could not fine gene name at 1575th line of gene edge
# could not fine gene name at 1576th line of gene edge
# could not fine gene name at 1577th line of gene edge
# could not fine gene name at 1578th line of gene edge
# could not fine gene name at 1579th line of gene edge
# could not fine gene name at 1580th line of gene edge
# could not fine gene name at 1581th line of gene edge
# could not fine gene name at 1582th line of gene edge
# could not fine gene name at 1583th line of gene edge
# could not fine gene name at 1584th line of gene edge
# could not fine gene name at 1585th line of gene edge
# could not fine gene name at 1586th line of gene edge
# could not fine gene name at 1587th line of gene edge
# could not fine gene name at 1588th line of gene edge
# could not fine gene name at 1589th line of gene edge
# could not fine gene name at 1590th line of gene edge
# could not fine gene name at 1591th line of gene edge
# could not fine gene name at 1592th line of gene edge
# could not fine gene name at 1593th line of gene edge
# could not fine gene name at 1594th line of gene edge
# could not fine gene name at 1595th line of gene edge
# could not fine gene name at 1596th line of gene edge
# could not fine gene name at 1597th line of gene edge
# could not fine gene name at 1659th line of gene edge
# could not fine gene name at 1688th line of gene edge
# could not fine gene name at 1689th line of gene edge
# could not fine gene name at 1690th line of gene edge
# could not fine gene name at 1691th line of gene edge
# could not fine gene name at 1692th line of gene edge
# could not fine gene name at 1693th line of gene edge
# could not fine gene name at 1694th line of gene edge
# could not fine gene name at 1695th line of gene edge
# could not fine gene name at 1696th line of gene edge
# could not fine gene name at 1697th line of gene edge
# could not fine gene name at 1698th line of gene edge
# could not fine gene name at 1699th line of gene edge
# could not fine gene name at 1700th line of gene edge
# could not fine gene name at 1701th line of gene edge
# could not fine gene name at 1702th line of gene edge
# could not fine gene name at 1703th line of gene edge
# could not fine gene name at 1704th line of gene edge
# could not fine gene name at 1705th line of gene edge
# could not fine gene name at 1706th line of gene edge
# could not fine gene name at 1707th line of gene edge
# could not fine gene name at 1708th line of gene edge
# could not fine gene name at 1709th line of gene edge
# could not fine gene name at 1710th line of gene edge
# could not fine gene name at 1711th line of gene edge
# could not fine gene name at 1712th line of gene edge
# could not fine gene name at 1713th line of gene edge
# could not fine gene name at 1714th line of gene edge
# could not fine gene name at 1715th line of gene edge
# could not fine gene name at 1716th line of gene edge
# could not fine gene name at 1717th line of gene edge
# could not fine gene name at 1718th line of gene edge
# could not fine gene name at 1719th line of gene edge
# could not fine gene name at 1720th line of gene edge
# could not fine gene name at 1721th line of gene edge
# could not fine gene name at 1722th line of gene edge
# could not fine gene name at 1723th line of gene edge
# could not fine gene name at 1724th line of gene edge
# could not fine gene name at 1725th line of gene edge
# could not fine gene name at 1726th line of gene edge
# could not fine gene name at 1727th line of gene edge
# could not fine gene name at 1793th line of gene edge
# could not fine gene name at 1795th line of gene edge
# could not fine gene name at 1836th line of gene edge
# could not fine gene name at 1838th line of gene edge
# could not fine gene name at 1879th line of gene edge
# could not fine gene name at 1954th line of gene edge
# could not fine gene name at 1956th line of gene edge
# could not fine gene name at 2026th line of gene edge
# could not fine gene name at 2028th line of gene edge
# could not fine gene name at 2032th line of gene edge
# could not fine gene name at 2080th line of gene edge
# could not fine gene name at 2082th line of gene edge
# could not fine gene name at 2130th line of gene edge
# could not fine gene name at 2132th line of gene edge
# could not fine gene name at 2338th line of gene edge
# could not fine gene name at 2340th line of gene edge
# could not fine gene name at 2454th line of gene edge
# could not fine gene name at 2456th line of gene edge
# could not fine gene name at 2557th line of gene edge
# could not fine gene name at 2559th line of gene edge
# could not fine gene name at 2649th line of gene edge
# could not fine gene name at 2651th line of gene edge
# could not fine gene name at 2722th line of gene edge
# could not fine gene name at 2870th line of gene edge
# could not fine gene name at 2962th line of gene edge
# could not fine gene name at 2964th line of gene edge
# could not fine gene name at 3019th line of gene edge
# could not fine gene name at 3021th line of gene edge
# could not fine gene name at 3212th line of gene edge
# could not fine gene name at 3214th line of gene edge
# could not fine gene name at 3453th line of gene edge
# could not fine gene name at 3455th line of gene edge
# could not fine gene name at 3514th line of gene edge
# could not fine gene name at 3516th line of gene edge
# could not fine gene name at 3575th line of gene edge
# could not fine gene name at 3577th line of gene edge
# could not fine gene name at 3680th line of gene edge
# could not fine gene name at 3682th line of gene edge
# could not fine gene name at 3779th line of gene edge
# could not fine gene name at 3781th line of gene edge
# could not fine gene name at 3924th line of gene edge
# could not fine gene name at 3926th line of gene edge
# could not fine gene name at 3950th line of gene edge
# could not fine gene name at 4125th line of gene edge
# could not fine gene name at 4127th line of gene edge
# could not fine gene name at 4192th line of gene edge
# could not fine gene name at 4194th line of gene edge
# could not fine gene name at 4260th line of gene edge
# could not fine gene name at 4262th line of gene edge
# could not fine gene name at 4329th line of gene edge
# could not fine gene name at 4331th line of gene edge
# could not fine gene name at 4399th line of gene edge
# could not fine gene name at 4401th line of gene edge
# could not fine gene name at 4430th line of gene edge
# could not fine gene name at 4555th line of gene edge
# could not fine gene name at 4557th line of gene edge
# could not fine gene name at 4693th line of gene edge
# could not fine gene name at 4695th line of gene edge
# could not fine gene name at 4782th line of gene edge
# could not fine gene name at 4784th line of gene edge
# could not fine gene name at 4817th line of gene edge
# could not fine gene name at 4894th line of gene edge
# could not fine gene name at 4896th line of gene edge
# could not fine gene name at 4986th line of gene edge
# could not fine gene name at 4988th line of gene edge
# could not fine gene name at 5130th line of gene edge
# could not fine gene name at 5132th line of gene edge
# could not fine gene name at 5318th line of gene edge
# could not fine gene name at 5320th line of gene edge
# could not fine gene name at 5488th line of gene edge
# could not fine gene name at 5490th line of gene edge
# could not fine gene name at 5568th line of gene edge
# could not fine gene name at 5570th line of gene edge
# could not fine gene name at 5660th line of gene edge
# could not fine gene name at 5661th line of gene edge
# could not fine gene name at 5771th line of gene edge
# could not fine gene name at 5773th line of gene edge
# could not fine gene name at 5853th line of gene edge
# could not fine gene name at 5855th line of gene edge
# could not fine gene name at 5930th line of gene edge
# could not fine gene name at 6064th line of gene edge
# could not fine gene name at 6065th line of gene edge
# could not fine gene name at 6066th line of gene edge
# could not fine gene name at 6067th line of gene edge
# could not fine gene name at 6068th line of gene edge
# could not fine gene name at 6069th line of gene edge
# could not fine gene name at 6070th line of gene edge
# could not fine gene name at 6071th line of gene edge
# could not fine gene name at 6072th line of gene edge
# could not fine gene name at 6073th line of gene edge
# could not fine gene name at 6074th line of gene edge
# could not fine gene name at 6075th line of gene edge
# could not fine gene name at 6076th line of gene edge
# could not fine gene name at 6077th line of gene edge
# could not fine gene name at 6078th line of gene edge
# could not fine gene name at 6079th line of gene edge
# could not fine gene name at 6080th line of gene edge
# could not fine gene name at 6081th line of gene edge
# could not fine gene name at 6082th line of gene edge
# could not fine gene name at 6083th line of gene edge
# could not fine gene name at 6084th line of gene edge
# could not fine gene name at 6085th line of gene edge
# could not fine gene name at 6086th line of gene edge
# could not fine gene name at 6087th line of gene edge
# could not fine gene name at 6088th line of gene edge
# could not fine gene name at 6089th line of gene edge
# could not fine gene name at 6090th line of gene edge
# could not fine gene name at 6091th line of gene edge
# could not fine gene name at 6092th line of gene edge
# could not fine gene name at 6093th line of gene edge
# could not fine gene name at 6094th line of gene edge
# could not fine gene name at 6095th line of gene edge
# could not fine gene name at 6096th line of gene edge
# could not fine gene name at 6097th line of gene edge
# could not fine gene name at 6098th line of gene edge
# could not fine gene name at 6099th line of gene edge
# could not fine gene name at 6100th line of gene edge
# could not fine gene name at 6101th line of gene edge
# could not fine gene name at 18999th line of gene edge
# could not fine gene name at 19213th line of gene edge
# could not fine gene name at 19366th line of gene edge
# could not fine gene name at 19514th line of gene edge
# could not fine gene name at 19717th line of gene edge
# could not fine gene name at 19768th line of gene edge
# could not fine gene name at 19902th line of gene edge
# could not fine gene name at 19904th line of gene edge
# could not fine gene name at 20266th line of gene edge
# could not fine gene name at 20624th line of gene edge
# could not fine gene name at 20677th line of gene edge
# could not fine gene name at 20740th line of gene edge
# could not fine gene name at 20897th line of gene edge
# could not fine gene name at 21183th line of gene edge
# could not fine gene name at 21398th line of gene edge
# could not fine gene name at 21551th line of gene edge
# could not fine gene name at 21688th line of gene edge
# could not fine gene name at 21848th line of gene edge
# could not fine gene name at 22049th line of gene edge
# could not fine gene name at 22275th line of gene edge
# could not fine gene name at 22369th line of gene edge
# could not fine gene name at 22371th line of gene edge
# could not fine gene name at 22495th line of gene edge
# could not fine gene name at 22601th line of gene edge
# could not fine gene name at 22694th line of gene edge
# could not fine gene name at 22894th line of gene edge
# could not fine gene name at 23281th line of gene edge
# could not fine gene name at 23474th line of gene edge
# could not fine gene name at 23914th line of gene edge
# could not fine gene name at 24228th line of gene edge
# could not fine gene name at 24367th line of gene edge
# could not fine gene name at 24479th line of gene edge
# could not fine gene name at 24540th line of gene edge
# could not fine gene name at 24837th line of gene edge
# could not fine gene name at 25156th line of gene edge
# could not fine gene name at 25563th line of gene edge
# could not fine gene name at 25731th line of gene edge
# could not fine gene name at 26010th line of gene edge
# could not fine gene name at 26234th line of gene edge
# could not fine gene name at 26434th line of gene edge
# could not fine gene name at 26637th line of gene edge
# could not fine gene name at 26831th line of gene edge
# could not fine gene name at 26912th line of gene edge
# could not fine gene name at 27026th line of gene edge
# could not fine gene name at 27391th line of gene edge
# could not fine gene name at 28003th line of gene edge
# could not fine gene name at 28145th line of gene edge
# could not fine gene name at 28452th line of gene edge
# could not fine gene name at 29204th line of gene edge
# could not fine gene name at 29582th line of gene edge
# could not fine gene name at 29879th line of gene edge
# could not fine gene name at 30105th line of gene edge
# could not fine gene name at 30239th line of gene edge
# could not fine gene name at 31149th line of gene edge
# could not fine gene name at 31509th line of gene edge
# could not fine gene name at 31613th line of gene edge
# could not fine gene name at 31746th line of gene edge
# could not fine gene name at 31945th line of gene edge
# could not fine gene name at 32178th line of gene edge
# could not fine gene name at 32545th line of gene edge
# could not fine gene name at 32652th line of gene edge
# could not fine gene name at 32900th line of gene edge
# could not fine gene name at 32901th line of gene edge
# could not fine gene name at 32902th line of gene edge
# could not fine gene name at 32903th line of gene edge
# could not fine gene name at 32904th line of gene edge
# could not fine gene name at 32905th line of gene edge
# could not fine gene name at 32906th line of gene edge
# could not fine gene name at 32907th line of gene edge
# could not fine gene name at 32908th line of gene edge
# could not fine gene name at 32909th line of gene edge
# could not fine gene name at 32910th line of gene edge
# could not fine gene name at 32911th line of gene edge
# could not fine gene name at 32912th line of gene edge
# could not fine gene name at 32913th line of gene edge
# could not fine gene name at 33362th line of gene edge
# could not fine gene name at 33363th line of gene edge
# could not fine gene name at 33364th line of gene edge
# could not fine gene name at 33365th line of gene edge
# could not fine gene name at 33366th line of gene edge
# could not fine gene name at 33367th line of gene edge
# could not fine gene name at 33368th line of gene edge
# could not fine gene name at 33369th line of gene edge
# could not fine gene name at 33370th line of gene edge
# could not fine gene name at 33371th line of gene edge
# could not fine gene name at 33372th line of gene edge
# could not fine gene name at 33373th line of gene edge
# could not fine gene name at 33374th line of gene edge
# could not fine gene name at 33375th line of gene edge
# could not fine gene name at 33376th line of gene edge
# could not fine gene name at 33377th line of gene edge
# ...
# could not fine gene name at 255533th line of gene edge
# could not fine gene name at 255534th line of gene edge
# could not fine gene name at 255535th line of gene edge
# could not fine gene name at 255536th line of gene edge
# could not fine gene name at 255537th line of gene edge
# could not fine gene name at 255538th line of gene edge
# could not fine gene name at 255539th line of gene edge
# could not fine gene name at 255540th line of gene edge
# could not fine gene name at 255541th line of gene edge
# could not fine gene name at 255542th line of gene edge
# could not fine gene name at 255543th line of gene edge
# could not fine gene name at 255544th line of gene edge
# could not fine gene name at 255545th line of gene edge
# could not fine gene name at 255546th line of gene edge
# could not fine gene name at 255547th line of gene edge
# could not fine gene name at 255548th line of gene edge
# could not fine gene name at 255549th line of gene edge
# could not fine gene name at 255550th line of gene edge
# could not fine gene name at 255551th line of gene edge
# could not fine gene name at 255552th line of gene edge
# could not fine gene name at 255553th line of gene edge
# could not fine gene name at 255554th line of gene edge
# could not fine gene name at 255555th line of gene edge
# could not fine gene name at 255556th line of gene edge
# could not fine gene name at 255557th line of gene edge
# could not fine gene name at 255558th line of gene edge
# could not fine gene name at 255559th line of gene edge
# could not fine gene name at 255560th line of gene edge
# could not fine gene name at 255561th line of gene edge
# could not fine gene name at 255562th line of gene edge
# could not fine gene name at 255563th line of gene edge
# could not fine gene name at 255564th line of gene edge
# could not fine gene name at 255565th line of gene edge
# could not fine gene name at 255566th line of gene edge
# could not fine gene name at 255567th line of gene edge
# could not fine gene name at 255568th line of gene edge
# could not fine gene name at 255569th line of gene edge
# could not fine gene name at 255570th line of gene edge
# could not fine gene name at 255571th line of gene edge
# could not fine gene name at 255572th line of gene edge
# could not fine gene name at 255573th line of gene edge
# could not fine gene name at 255574th line of gene edge
# could not fine gene name at 255575th line of gene edge
# could not fine gene name at 255576th line of gene edge
# could not fine gene name at 255577th line of gene edge
# could not fine gene name at 255578th line of gene edge
# could not fine gene name at 255579th line of gene edge
# could not fine gene name at 255580th line of gene edge
# could not fine gene name at 255581th line of gene edge
# could not fine gene name at 255582th line of gene edge
# could not fine gene name at 255583th line of gene edge
# could not fine gene name at 255584th line of gene edge
# could not fine gene name at 255585th line of gene edge
# could not fine gene name at 255586th line of gene edge
# could not fine gene name at 255587th line of gene edge
# could not fine gene name at 255588th line of gene edge
# could not fine gene name at 255589th line of gene edge
# could not fine gene name at 255590th line of gene edge
# could not fine gene name at 255591th line of gene edge
# could not fine gene name at 255592th line of gene edge
# could not fine gene name at 255593th line of gene edge
# could not fine gene name at 255594th line of gene edge
# could not fine gene name at 255595th line of gene edge
# could not fine gene name at 255596th line of gene edge
# could not fine gene name at 255597th line of gene edge
# could not fine gene name at 255598th line of gene edge
# could not fine gene name at 255599th line of gene edge
# could not fine gene name at 255600th line of gene edge
# could not fine gene name at 255601th line of gene edge
# could not fine gene name at 255602th line of gene edge
# could not fine gene name at 255603th line of gene edge
# could not fine gene name at 255604th line of gene edge
# could not fine gene name at 255605th line of gene edge
# could not fine gene name at 255606th line of gene edge
# could not fine gene name at 255607th line of gene edge
# could not fine gene name at 255608th line of gene edge
# could not fine gene name at 255609th line of gene edge
# could not fine gene name at 255610th line of gene edge
# could not fine gene name at 255611th line of gene edge
# could not fine gene name at 255612th line of gene edge
# could not fine gene name at 255613th line of gene edge
# could not fine gene name at 255614th line of gene edge
# could not fine gene name at 255615th line of gene edge
# could not fine gene name at 255616th line of gene edge
# could not fine gene name at 255617th line of gene edge
# could not fine gene name at 255618th line of gene edge
# could not fine gene name at 255640th line of gene edge
# could not fine gene name at 255893th line of gene edge
# could not fine gene name at 257200th line of gene edge
# could not fine gene name at 257646th line of gene edge
# could not fine gene name at 258001th line of gene edge
# could not fine gene name at 258255th line of gene edge
# could not fine gene name at 258388th line of gene edge
# could not fine gene name at 258783th line of gene edge
# could not fine gene name at 258784th line of gene edge
# could not fine gene name at 258785th line of gene edge
# could not fine gene name at 258786th line of gene edge
# could not fine gene name at 258787th line of gene edge
# could not fine gene name at 258795th line of gene edge
# could not fine gene name at 258896th line of gene edge
# could not fine gene name at 259708th line of gene edge
# could not fine gene name at 259709th line of gene edge
# could not fine gene name at 259710th line of gene edge
# could not fine gene name at 259711th line of gene edge
# could not fine gene name at 259712th line of gene edge
# could not fine gene name at 259713th line of gene edge
# could not fine gene name at 259714th line of gene edge
# could not fine gene name at 259715th line of gene edge
# could not fine gene name at 259716th line of gene edge
# could not fine gene name at 259717th line of gene edge
# could not fine gene name at 259718th line of gene edge
# could not fine gene name at 259719th line of gene edge
# could not fine gene name at 259720th line of gene edge
# could not fine gene name at 259721th line of gene edge
# could not fine gene name at 259722th line of gene edge
# could not fine gene name at 259723th line of gene edge
# could not fine gene name at 259724th line of gene edge
# could not fine gene name at 259725th line of gene edge
# could not fine gene name at 259726th line of gene edge
# could not fine gene name at 259727th line of gene edge
# could not fine gene name at 259728th line of gene edge
# could not fine gene name at 259729th line of gene edge
# could not fine gene name at 259730th line of gene edge
# could not fine gene name at 259731th line of gene edge
# could not fine gene name at 259732th line of gene edge
# could not fine gene name at 259733th line of gene edge
# could not fine gene name at 259734th line of gene edge
# could not fine gene name at 259735th line of gene edge
# could not fine gene name at 259736th line of gene edge
# could not fine gene name at 259737th line of gene edge
# could not fine gene name at 259738th line of gene edge
# could not fine gene name at 259739th line of gene edge
# could not fine gene name at 259740th line of gene edge
# could not fine gene name at 259741th line of gene edge
# could not fine gene name at 259742th line of gene edge
# could not fine gene name at 259743th line of gene edge
# could not fine gene name at 259744th line of gene edge
# could not fine gene name at 259745th line of gene edge
# could not fine gene name at 259746th line of gene edge
# could not fine gene name at 259747th line of gene edge
# could not fine gene name at 259748th line of gene edge
# could not fine gene name at 259749th line of gene edge
# could not fine gene name at 259750th line of gene edge
# could not fine gene name at 259751th line of gene edge
# could not fine gene name at 259752th line of gene edge
# could not fine gene name at 259753th line of gene edge
# could not fine gene name at 259754th line of gene edge
# could not fine gene name at 259755th line of gene edge
# could not fine gene name at 259756th line of gene edge
# could not fine gene name at 259757th line of gene edge
# could not fine gene name at 259758th line of gene edge
# could not fine gene name at 259759th line of gene edge
# could not fine gene name at 259760th line of gene edge
# could not fine gene name at 259761th line of gene edge
# could not fine gene name at 259762th line of gene edge
# could not fine gene name at 259763th line of gene edge
# could not fine gene name at 259764th line of gene edge
# could not fine gene name at 259765th line of gene edge
# could not fine gene name at 259766th line of gene edge
# could not fine gene name at 259767th line of gene edge
# could not fine gene name at 259768th line of gene edge
# could not fine gene name at 259769th line of gene edge
# could not fine gene name at 259770th line of gene edge
# could not fine gene name at 259771th line of gene edge
# could not fine gene name at 259772th line of gene edge
# could not fine gene name at 259773th line of gene edge
# could not fine gene name at 259774th line of gene edge
# could not fine gene name at 259775th line of gene edge
# could not fine gene name at 259776th line of gene edge
# could not fine gene name at 259777th line of gene edge
# could not fine gene name at 259778th line of gene edge
# could not fine gene name at 259779th line of gene edge
# could not fine gene name at 259780th line of gene edge
# could not fine gene name at 259781th line of gene edge
# could not fine gene name at 259782th line of gene edge
# could not fine gene name at 259783th line of gene edge
# could not fine gene name at 259784th line of gene edge
# could not fine gene name at 259785th line of gene edge
# could not fine gene name at 259786th line of gene edge
# could not fine gene name at 259787th line of gene edge
# could not fine gene name at 259788th line of gene edge
# could not fine gene name at 259789th line of gene edge
# could not fine gene name at 259790th line of gene edge
# could not fine gene name at 259791th line of gene edge
# could not fine gene name at 259792th line of gene edge
# could not fine gene name at 259793th line of gene edge
# could not fine gene name at 259794th line of gene edge
# could not fine gene name at 259795th line of gene edge
# could not fine gene name at 259796th line of gene edge
# could not fine gene name at 259797th line of gene edge
# could not fine gene name at 259798th line of gene edge
# could not fine gene name at 259799th line of gene edge
# could not fine gene name at 259800th line of gene edge
# could not fine gene name at 259801th line of gene edge
# could not fine gene name at 259802th line of gene edge
# could not fine gene name at 259803th line of gene edge
# could not fine gene name at 259804th line of gene edge
# could not fine gene name at 259805th line of gene edge
# could not fine gene name at 259806th line of gene edge
# could not fine gene name at 259807th line of gene edge
# could not fine gene name at 259808th line of gene edge
# could not fine gene name at 259809th line of gene edge
# could not fine gene name at 259810th line of gene edge
# could not fine gene name at 259811th line of gene edge
# could not fine gene name at 259812th line of gene edge
# could not fine gene name at 259813th line of gene edge
# could not fine gene name at 259814th line of gene edge
# could not fine gene name at 259815th line of gene edge
# could not fine gene name at 259816th line of gene edge
# could not fine gene name at 259817th line of gene edge
# could not fine gene name at 259818th line of gene edge
# could not fine gene name at 259819th line of gene edge
# could not fine gene name at 259820th line of gene edge
# could not fine gene name at 259821th line of gene edge
# could not fine gene name at 259822th line of gene edge
# could not fine gene name at 259823th line of gene edge
# could not fine gene name at 259824th line of gene edge
# could not fine gene name at 259825th line of gene edge
# could not fine gene name at 259826th line of gene edge
# could not fine gene name at 259827th line of gene edge
# could not fine gene name at 259828th line of gene edge
# could not fine gene name at 259829th line of gene edge
# could not fine gene name at 259830th line of gene edge
# could not fine gene name at 259831th line of gene edge
# could not fine gene name at 259832th line of gene edge
# could not fine gene name at 259833th line of gene edge
# could not fine gene name at 259834th line of gene edge
# could not fine gene name at 259835th line of gene edge
# could not fine gene name at 259836th line of gene edge
# could not fine gene name at 259837th line of gene edge
# could not fine gene name at 259838th line of gene edge
# could not fine gene name at 259839th line of gene edge
# could not fine gene name at 259840th line of gene edge
# could not fine gene name at 259841th line of gene edge
# could not fine gene name at 259842th line of gene edge
# could not fine gene name at 259843th line of gene edge
# could not fine gene name at 259844th line of gene edge
# could not fine gene name at 259845th line of gene edge
# could not fine gene name at 259846th line of gene edge
# could not fine gene name at 259847th line of gene edge
# could not fine gene name at 259848th line of gene edge
# could not fine gene name at 259849th line of gene edge
# could not fine gene name at 259850th line of gene edge
# could not fine gene name at 259851th line of gene edge
# could not fine gene name at 259852th line of gene edge
# could not fine gene name at 259853th line of gene edge
# could not fine gene name at 259854th line of gene edge
# could not fine gene name at 259855th line of gene edge
# could not fine gene name at 259856th line of gene edge
# could not fine gene name at 259857th line of gene edge
# could not fine gene name at 259858th line of gene edge
# could not fine gene name at 259859th line of gene edge
# could not fine gene name at 259860th line of gene edge
# could not fine gene name at 259861th line of gene edge
# could not fine gene name at 259862th line of gene edge
# could not fine gene name at 259863th line of gene edge
# could not fine gene name at 259864th line of gene edge
# could not fine gene name at 259865th line of gene edge
# could not fine gene name at 259866th line of gene edge
# could not fine gene name at 259867th line of gene edge
# could not fine gene name at 259868th line of gene edge
# could not fine gene name at 259869th line of gene edge
# could not fine gene name at 259870th line of gene edge
# could not fine gene name at 259871th line of gene edge
# could not fine gene name at 259872th line of gene edge
# could not fine gene name at 259873th line of gene edge
# could not fine gene name at 259874th line of gene edge
# could not fine gene name at 259875th line of gene edge
# could not fine gene name at 259876th line of gene edge
# could not fine gene name at 259877th line of gene edge
# could not fine gene name at 259878th line of gene edge
# could not fine gene name at 259879th line of gene edge
# could not fine gene name at 259880th line of gene edge
# could not fine gene name at 259881th line of gene edge
# could not fine gene name at 259882th line of gene edge
# could not fine gene name at 259883th line of gene edge
# could not fine gene name at 259884th line of gene edge
# could not fine gene name at 259885th line of gene edge
# could not fine gene name at 259886th line of gene edge
# could not fine gene name at 259887th line of gene edge
# could not fine gene name at 259888th line of gene edge
# could not fine gene name at 259889th line of gene edge
# could not fine gene name at 259890th line of gene edge
# could not fine gene name at 259891th line of gene edge
# could not fine gene name at 259892th line of gene edge
# could not fine gene name at 259893th line of gene edge
# could not fine gene name at 259894th line of gene edge
# could not fine gene name at 259895th line of gene edge
# could not fine gene name at 259896th line of gene edge
# could not fine gene name at 259897th line of gene edge

# %%
node_map['Gusb']
# Out:
# 1423

# %%
edge_list = torch.tensor(np.array(edge_list).T, dtype=torch.long)

# %%
edge_list.size()
# Out:
# torch.Size([2, 492746])

# %%
# load training data
train_loader = []
with open('input_train_cat.csv') as csvfile: 
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC)
    for row in reader: 
        
        # index 1423 is Gusb gene
        target_expression_level = torch.tensor(copy.copy(row[1423]), dtype=torch.float).view(1, 1)
        row[1423] = 0
        
        # create graph
        data = Data(x=torch.tensor(row, dtype=torch.float).view(1431, 1), 
                    y=target_expression_level, edge_index=edge_list)
        train_loader.append(data)

# %%
from torch_geometric.data import Batch

# %%
# load validation data
validate_loader = []
with open('input_test_cat.csv') as csvfile: 
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC)
    for row in reader: 
        
        # index 1423 is Gusb gene
        target_expression_level = torch.tensor(copy.copy(row[1423]), dtype=torch.float).view(1, 1)
        row[1423] = 0
        
        # create graph
        data = Data(x=torch.tensor(row, dtype=torch.float).view(1431, 1), 
                    y=target_expression_level, edge_index=edge_list)
        validate_loader.append(data)

# %%
print(len(train_loader))
print(len(validate_loader))
# Out:
# 18542
# 4636

# %%
print(train_loader[0].x.size())
print(train_loader[0].y.size())
print(train_loader[0].edge_index.size())
# Out:
# torch.Size([1431, 1])
# torch.Size([1, 1])
# torch.Size([2, 492746])

# %% [markdown]
# ## Define GCN

# %%
class GCNInferenceNetwork(nn.Module): 
    def __init__(self, d=1): 
        super(GCNInferenceNetwork, self).__init__()
        self.conv1 = GCNConv(d, 16)
        self.conv2 = GCNConv(16, 16)
        self.fc    = nn.Linear(16, 1)
    
    def forward(self, graph): 
        x, edges, y = graph.x, graph.edge_index, graph.y
        
        x = self.conv1(x, edges)
        x = F.relu(x)
        x = self.conv2(x, edges)
        x = F.relu(x)
        # x = global_mean_pool(x, torch.zeros(graph.num_nodes, dtype=torch.long))
        x = global_mean_pool(x, graph.batch)
        
        x = self.fc(x)
        
        return x

# %%
for parameter in model.parameters():
    print(parameter.size())
# Out:
# torch.Size([1, 32])
# torch.Size([32])
# torch.Size([32, 32])
# torch.Size([32])
# torch.Size([1, 32])
# torch.Size([1])

# %% [markdown]
# ## Train GCN

# %%
batch_size = 32
def train(model, train_loader): 
    model.train()
    optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)
    loss_fn = nn.MSELoss()
    loss_all = 0
    
    def new_fun(): 
        sample_ids = np.random.randint(len(train_loader), size=batch_size)
        batch_1 = [train_loader[j].to(torch.device('cuda')) for j in sample_ids]
        batch = Batch.from_data_list(batch_1).to(torch.device('cuda'))
        x, edges, y = batch.x, batch.edge_index, batch.y
        pred_ = model(batch)
        loss = loss_fn(pred_, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        del pred_
        del batch
        for exp in batch_1:
            del exp
        del batch_1
        del x
        del edges
        del y
        
        return loss.item()

        if i%2 == 0: 
            print('%d batches trained' %i)
    
    for i in range(len(train_loader) // batch_size):
        loss_all += new_fun()
    
    return loss_all / len(train_loader)

# %%
def validate(model, validate_loader): 
    model.evaluate()
    loss_fn = nn.MSELoss()
    loss_all = 0
    
    for data in validate_loader: 
        x, edges, y = data.x, data.edge_index, data.y
        pred_ = model(data)
        loss = loss_fn(pred_, y)
        loss_all += loss.item()
    
    return loss_all / len(validate_loader)

# %%
model = GCNInferenceNetwork().to(torch.device('cuda'))

epoches = 1
for i in range(epoches): 
    train_loss = train(model, train_loader)
    # val_loss = validate(model, validate_loader)
    # print ('epoches: %d || train_losses: %f || val_loss: %f' %(i, train_loss, val_loss))
    print ('epoches: %d || train_losses: %f' %(i, train_loss))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-028300144442> in <module>
#       3 epoches = 1
#       4 for i in range(epoches):
# ----> 5     train_loss = train(model, train_loader)
#       6     # val_loss = validate(model, validate_loader)
#       7     # print ('epoches: %d || train_losses: %f || val_loss: %f' %(i, train_loss, val_loss))
#
# <ipython-input-11-74adc82a0e88> in train(model, train_loader)
#      33
#      34     for i in range(len(train_loader) // batch_size):
# ---> 35         loss_all += new_fun()
#      36
#      37     return loss_all / len(train_loader)
#
# <ipython-input-11-74adc82a0e88> in new_fun()
#      11         batch = Batch.from_data_list(batch_1).to(torch.device('cuda'))
#      12         x, edges, y = batch.x, batch.edge_index, batch.y
# ---> 13         pred_ = model(batch)
#      14         loss = loss_fn(pred_, y)
#      15
#
# /opt/tljh/user/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-10-c396484e3a0c> in forward(self, graph)
#       9         x, edges, y = graph.x, graph.edge_index, graph.y
#      10
# ---> 11         x = self.conv1(x, edges)
#      12         x = F.relu(x)
#      13         x = self.conv2(x, edges)
#
# /opt/tljh/user/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /opt/tljh/user/lib/python3.7/site-packages/torch_geometric/nn/conv/gcn_conv.py in forward(self, x, edge_index, edge_weight)
#     107         edge_index, norm = self.cached_result
#     108
# --> 109         return self.propagate(edge_index, x=x, norm=norm)
#     110
#     111     def message(self, x_j, norm):
#
# /opt/tljh/user/lib/python3.7/site-packages/torch_geometric/nn/conv/message_passing.py in propagate(self, edge_index, size, **kwargs)
#     256         if mp_type == 'edge_index' or self.__fuse__ is False:
#     257             msg_kwargs = self.__distribute__(self.__msg_params__, kwargs)
# --> 258             out = self.message(**msg_kwargs)
#     259
#     260             aggr_kwargs = self.__distribute__(self.__aggr_params__, kwargs)
#
# /opt/tljh/user/lib/python3.7/site-packages/torch_geometric/nn/conv/gcn_conv.py in message(self, x_j, norm)
#     110
#     111     def message(self, x_j, norm):
# --> 112         return norm.view(-1, 1) * x_j if norm is not None else x_j
#     113
#     114     def update(self, aggr_out):
#
# RuntimeError: CUDA out of memory. Tried to allocate 966.00 MiB (GPU 0; 11.17 GiB total capacity; 8.42 GiB already allocated; 677.31 MiB free; 10.19 GiB reserved in total by PyTorch)
