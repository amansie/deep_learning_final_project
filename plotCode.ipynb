# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
# %precision 16

# PLOTTING
plt.rcParams['lines.linewidth'] = 3  
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 15}          
plt.rc('font', **font)

csfont = {'fontname':'Serif'}
plt.rcParams["font.family"] = "Arial"
plt.rcParams['figure.figsize'] = 6, 5
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['figure.facecolor'] = 'white'

# %%
# load data
cnn_1d_data = -np.log(np.loadtxt('dylan-cnn_1-dim_2-layer_mse.txt'))
cnn_37x37_data= -np.log(np.loadtxt('37x37_pearson_mse.txt'))
linear_data = -np.log(np.loadtxt('linear_regression_results_ka2461.txt'))
dnn_data = -np.log(np.loadtxt('dnn_mse_result.txt'))

# %%
# plot
labels = ['Apoe', 'App', 'Gusb', 'Lamp5', 'Mbp', 'Pvalb', 'Rorb', 'S100b', 'Slc30a3', 'Snca']
x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots(figsize=(15, 10))
rects1 = ax.bar(x - width*1.5, cnn_1d_data, width, label='CNN_1D')
rects2 = ax.bar(x - width/2, cnn_37x37_data, width, label='VGG16')
rects3 = ax.bar(x + width/2, linear_data, width, label='LINEAR')
rects4 = ax.bar(x + width*1.5, dnn_data, width, label='DNN')

ax.set_ylabel('-log(MSE)')
ax.set_title('MSE By Different Models')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.savefig('model_compare.jpg')
plt.show()
